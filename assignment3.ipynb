# %% [markdown]
# # ECE 493 Assignment 3
#
# Assignment Overview
# - Learn pytorch and helper libraries
# - Understand VOC Sementic Segmentation Dataset
# - Create data transforms to augment the dataset
# - Create the neural network
# - Train and evaluate the neural network
#
# Problems:
# - 1) Data augmentation
# - 2) Create the neural network
#
# Note:
# - This assignment was created based on assignment 4 of CS 484
#  - https://cs.uwaterloo.ca/~yboykov/Courses/cs484/

# %% [markdown]
# # Importing libraries
#
# Everything that you need for this assignment is imported here.
#
# The VoxSegmentation dataset contains images and segmented images.
# https://chainercv.readthedocs.io/en/stable/reference/datasets.html#chainercv.datasets.VOCSemanticSegmentationDataset

# %%
# You can run this cell to install packages
# I believe this is the only package not preinstalled on google colab
# !pip install chainercv
# Out:
# Requirement already satisfied: chainercv in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: chainer>=6.0 in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.0.12)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.19.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (53.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.7.4.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.15.0)

# %%
# pytorch library
import torch
# neural network layers (Conv2d, Linear, etc.) that will be trained
# https://pytorch.org/docs/stable/nn.html
import torch.nn as nn
# Many functions (convolution, pooling, activation, etc.)
# https://pytorch.org/docs/stable/nn.functional.html
import torch.nn.functional as F
# https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader
from torch.utils.data import DataLoader

# Contains pretrained models for transfer learning
# https://pytorch.org/docs/stable/torchvision/models.html
import torchvision.models as models
# import data transforms
# https://pytorch.org/docs/stable/torchvision/transforms.html
# Take note of transforms.ToPILImage and transforms.ToTensor
import torchvision.transforms as transforms


# Use cuda on the gpu or use the cpu
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# Overide device when testing on CPU
# device = 'cpu'

# graphing and images
import matplotlib.pyplot as plt
from PIL import Image

# numpy
import numpy as np

# deepcopy the nn
import copy

# for random number generation
import random

# chainerCV is similar to torchvision
import chainercv
# https://chainercv.readthedocs.io/en/stable/reference/datasets.html#chainercv.datasets.VOCSemanticSegmentationDataset
from chainercv.datasets import VOCSemanticSegmentationDataset
# https://docs.chainer.org/en/stable/reference/generated/chainer.datasets.TransformDataset.html#chainer.datasets.TransformDataset
from chainer.datasets import TransformDataset

# Used to calculate mIoU
from chainercv.evaluations import eval_semantic_segmentation

# %% [markdown]
# # Import VOC Segmentation Dataset

# %%
import os.path
from os import path
from google.colab import drive

drive.mount('/content/gdrive')
DATASET_LOCATION = '/content/gdrive/MyDrive/'

if not path.exists(DATASET_LOCATION + 'VOC2012'):
  print('First time run, downloading VOC and copying to permanent location')
  # auto will download the dataset to $HOME/.chainer/dataset
  # This gets deleted when you disconnect from google colab
  voc_train_data = VOCSemanticSegmentationDataset(data_dir='auto', split='train')
  # !cp -r $HOME/.chainer/dataset/pfnet/chainercv/voc/VOCdevkit/VOC2012/ /content/gdrive/MyDrive/

# Instantiate the data loader with the dataset directory
voc_train_data = VOCSemanticSegmentationDataset(data_dir=DATASET_LOCATION + 'VOC2012', split='train')

print("Number of training examples:", len(voc_train_data))
print("Each with one image and one ground truth (gt) segmented image:", len(voc_train_data[0]))

print("Image Shape:", voc_train_data[0][0].shape)
print("Segmented Image Shape:", voc_train_data[0][1].shape)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Number of training examples: 1464
# Each with one image and one ground truth (gt) segmented image: 2
# Image Shape: (3, 281, 500)
# Segmented Image Shape: (281, 500)

# %% [markdown]
# There are 22 Classes in VOC.
#
# https://github.com/NVIDIA/DIGITS/blob/master/examples/semantic-segmentation/pascal-voc-classes.txt
# - -1 is ignore
# - 0 is background
# - 1-20 are different objects

# %%
# Find images with people and cars
def find_car_and_ppl_images():
    car_label = 7
    person_label = 15
    count = 0
    max_count = 100
    for i in range(len(voc_train_data)):
        tmp_count = np.unique(voc_train_data[i][1], return_counts=True)
        if car_label in tmp_count[0] and person_label in tmp_count[0]:
            if count == max_count:
                break
            else:
                img, label = voc_train_data[i]
                fig = plt.figure(figsize=(4,3))
                ax = fig.add_subplot(1,1,1)
                plt.title('Image ' + str(i))
                ax.imshow(np.rollaxis(img.astype(int), 0, 3))
                count += 1

# I used this function to find some relevant images
# find_car_and_ppl_images()

# Some relevant image indexes for a self-driving car
# Car = 119, 273, Bicycle = 225
img_119, seg_img_119 = voc_train_data[119]
img_273, seg_img_273 = voc_train_data[273]
img_225, seg_img_225 = voc_train_data[225]

print("View count of pixels within each label category:")
print(np.unique(voc_train_data[119][1], return_counts=True))
print(np.unique(voc_train_data[273][1], return_counts=True))
print(np.unique(voc_train_data[225][1], return_counts=True))

print("We must move the RGB channel to the back to be viewed with plt:")
print("Before:", img_119.shape)
print("After:", np.rollaxis(img_119, 0, 3).shape)

print("Lastly let's verify that the image and gt label match")

# This colorize_mask class takes in a numpy segmentation mask,
#  and then converts it to a PIL Image for visualization.
#  Since by default the numpy matrix contains integers from
#  0,1,...,num_classes, we need to apply some color to this
#  so we can visualize easier! Refer to:
#  https://pillow.readthedocs.io/en/4.1.x/reference/Image.html#PIL.Image.Image.putpalette
palette = [0, 0, 0, 128, 0, 0, 0, 128, 0, 128, 128, 0, 0, 0, 128, 128, 0, 128, 0, 128, 128,
           128, 128, 128, 64, 0, 0, 192, 0, 0, 64, 128, 0, 192, 128, 0, 64, 0, 128, 192, 0, 128,
           64, 128, 128, 192, 128, 128, 0, 64, 0, 128, 64, 0, 0, 192, 0, 128, 192, 0, 0, 64, 128]

def colorize_mask(mask):
    new_mask = Image.fromarray(mask.astype(np.uint8)).convert('P')
    new_mask.putpalette(palette)

    return new_mask

def add_img_plot(fig, index, img, title, sub_plot_id):
    ax = fig.add_subplot(sub_plot_id[0],sub_plot_id[1],sub_plot_id[2])
    plt.title(title + str(index))
    ax.imshow(img)

# Create the figure size
fig = plt.figure(figsize=(10,10))
# Car image 119
add_img_plot(fig, 119, np.rollaxis(img_119.astype(int), 0, 3), 'Image ', [3,2,1])
add_img_plot(fig, 119, colorize_mask(seg_img_119), 'Segmented Image ', [3,2,2])
# Car image 273
add_img_plot(fig, 273, np.rollaxis(img_273.astype(int), 0, 3), 'Image ', [3,2,3])
add_img_plot(fig, 273, colorize_mask(seg_img_273), 'Segmented Image ', [3,2,4])
# Bicycle image 225
add_img_plot(fig, 225, np.rollaxis(img_225.astype(int), 0, 3), 'Image ', [3,2,5])
add_img_plot(fig, 225, colorize_mask(seg_img_225), 'Segmented Image ', [3,2,6])
# Out:
# View count of pixels within each label category:
# (array([-1,  0,  7, 15], dtype=int32), array([  4943, 142234,  15733,   3590]))
# (array([-1,  0,  7, 15], dtype=int32), array([  3684, 150374,  32709,    733]))
# (array([-1,  0,  2,  7, 15], dtype=int32), array([ 12802, 164053,   4518,    673,   5454]))
# We must move the RGB channel to the back to be viewed with plt:
# Before: (3, 333, 500)
# After: (333, 500, 3)
# Lastly let's verify that the image and gt label match

# %% [markdown]
# # Problem 1 Data Augmentation
#
# The transform below is used to create a transformed training dataset. It currently center crops all images.
#
# Modify it so that:
# - There is a 50% chance the images will be flipped horizontally
# - Instead of a center crop, a random part of the image is cropped
#
# Useful functions:
# - chainercv.transforms.flip
# - chainercv.transforms.random_crop
#
# Note: The output image and segmented images should match

# %%
# From ImageNet
norm = ([0.485, 0.456, 0.406], 
        [0.229, 0.224, 0.225])

# Modify this function
def voc_train_transform(in_data):
    size = (110,110)
    img, seg_img = in_data
  
    # Add channel
    seg_img = seg_img[None] # convert to 3-D

    # we can use random flip to flip the image horizontally or vertically with 50 50 probability
    chance = random.choice([True, False])
    if(chance):
      img = chainercv.transforms.flip(img, y_flip = False, x_flip = True, copy = False)
      seg_img = chainercv.transforms.flip(seg_img, y_flip = False, x_flip = True, copy = False)
    
    # instead of centre crop we need to do a random crop  
    img, param = chainercv.transforms.random_crop(img, size, True)

    seg_img = seg_img[:, param["y_slice"], param["x_slice"]]
    
 
 
    img = np.rollaxis(img, 0, 3)
    img = transforms.ToPILImage()(np.uint8(img))
    img = transforms.ToTensor()(img)
    img = transforms.Normalize(norm[0],norm[1])(img)

  

    seg_img = seg_img[0] #convert to 2-D
    
    return img, torch.from_numpy(seg_img.copy()).long()

img_119, seg_img_119 = voc_train_transform(voc_train_data[119])
img_273, seg_img_273 = voc_train_transform(voc_train_data[273])
img_225, seg_img_225 = voc_train_transform(voc_train_data[225])

# Create the figure size
fig = plt.figure(figsize=(10,10))
# Car image 119
add_img_plot(fig, 119, transforms.ToPILImage()(img_119), 'Image ', [3,2,1])
add_img_plot(fig, 119, colorize_mask(seg_img_119.numpy()), 'Segmented Image ', [3,2,2])
# Car image 273
add_img_plot(fig, 273, transforms.ToPILImage()(img_273), 'Image ', [3,2,3])
add_img_plot(fig, 273, colorize_mask(seg_img_273.numpy()), 'Segmented Image ', [3,2,4])
# Bicycle image 225
add_img_plot(fig, 225, transforms.ToPILImage()(img_225), 'Image ', [3,2,5])
add_img_plot(fig, 225, colorize_mask(seg_img_225.numpy()), 'Segmented Image ', [3,2,6])

# %% [markdown]
# # Dataloader

# %%
voc_train_data_transformed = TransformDataset(voc_train_data, voc_train_transform)

# epoch = one iteration over the entire dataset
# batch size = samples per batch within an epoch
# shuffle = Set to True if your data is ordered
# num_workers = number of subprocess to use when dataloading, set higher if you have many cpu cores
if device == 'cpu':
    train_loader = DataLoader(voc_train_data_transformed, batch_size=5, shuffle=True, num_workers=10)
else:
    train_loader = DataLoader(voc_train_data_transformed, batch_size=50, shuffle=True, num_workers=2)

# %% [markdown]
# # Problem 2 Create the neural network

# %%
class Net(nn.Module):
    def __init__(self, num_classes, criterion=None):
        super(Net, self).__init__()
        self.criterion = criterion
        self.num_classes = num_classes

        #batch size is the number of images fed to train the network
        # channels are layers of information (they can be color layers ect)
        #torch.Size([1, 3, 110, 110])
                      #batch size, channels (depth), height, width
        # Hints:
        # Useful layers to train
        # - nn.Conv2d
        # - nn.BatchNorm2d
        # - nn.Dropout2d
        # You can import a pre-trained model
        self.resnet = models.resnet34(pretrained=True)
        self.conv6 = nn.Conv2d(576, 288, 3, 1)
        self.conv7 = nn.Conv2d(288, 21, 1, 1)

        self.b2n3 = nn.BatchNorm2d(288)
        self.b2n4 = nn.BatchNorm2d(21)

        self.Dropout2d1 = nn.Dropout2d(p = 0.5)

        #self.conv1 = nn.Conv2d(1, 32, 3, 1)
                                #in channels (what the inputs channel number is )
                                #out channels number (what u want the channel number to be)
    def forward(self, inp, gts=None):
        # Fill in

        # Hints: Useful functions
        # - F.relu        (neuron activation)
        # - F.interpolate (interpolate to increase tensor H and W)
        # - torch.cat     (concatonate tensors to implement a skip connection)


        output_size = (inp.size()[2], inp.size()[3])
        # print("output size is : ", output_size)
        # 5 (pre-trained) convolutional layers from "resnet" 
        
        # print("LAYER 1")
        x = self.resnet.conv1(inp) 

        # print("2d size : ", inp.size())
        x = self.resnet.bn1(x)
        x = self.resnet.relu(x)
        x = self.resnet.maxpool(x)

        #print("LAYER 2")
        x = self.resnet.layer1(x) 
        skip_conection = x

        # print(skip_conection.size()[2])
        
       # print("LAYER 3")
        x = self.resnet.layer2(x)
       
        #print("LAYER 4")
        x = self.resnet.layer3(x)

        #print("LAYER 5")
        x = self.resnet.layer4(x)
    
        #interpolation to layer 3 size 
        w = skip_conection.size()[2]
        h = skip_conection.size()[3]
        x = F.interpolate(x, size = (w,h) )
        # going from layer 4 to Decodeded layer 1
        # sum of output from exit of layer 2 with exit of layer 4 

        # print("Size of X ", x.size())
        # print("Size of skip_connection", skip_conection.size())
        x = torch.cat((x, skip_conection), dim=1)
        

        x = self.conv6(x)
        x = self.b2n3(x)
        x = self.resnet.relu(x)
        x = self.Dropout2d1(x)

        x = F.interpolate(x, (output_size[0] , output_size[1]) ) 
    
        #print("LAYER Final")

        x = self.conv7(x)
        x = self.b2n4(x)
        # x = F.interpolate(x, 110)

        # print(" Final size is : ", x.size())
        lfinal = x
        # print("lfinal size is : ", lfinal.size())
        if self.training:
            # Return the loss if in training mode
            return self.criterion(lfinal, gts)
        else:
            # Return the actual prediction otherwise
            return lfinal

# %%
untrained_net = Net(21).to(device)
untrained_net.eval()

sample_img, sample_target = voc_train_data_transformed[119]

untrained_output = untrained_net.forward(sample_img[None].to(device))
if device != 'cpu':
    untrained_output = untrained_output.cpu()
untrained_nn_seg_img_119 = torch.argmax(untrained_output.cpu(), dim=1).numpy()[0]

# Create the figure size
fig = plt.figure(figsize=(8,2))
# Car image 119
add_img_plot(fig, 119, transforms.ToPILImage()(img_119), 'Image ', [1,3,1])
add_img_plot(fig, 119, colorize_mask(seg_img_119.numpy()), 'GT Segmented Image ', [1,3,2])
add_img_plot(fig, 119, colorize_mask(untrained_nn_seg_img_119), 'NN Segmented Image', [1,3,3])
# Out:
# output size is :  (110, 110)
# lfinal size is :  torch.Size([1, 21, 110, 110])

# %%
def train(train_loader, net, optimizer, loss_graph, device):

    for batch_idx, (data, target) in enumerate(train_loader):
        img, gt_seg_img = data.to(device), target.to(device)

        # This is a forward pass which also returns loss due to training mode
        main_loss = net(img, gts=gt_seg_img)

        # Populate this list to graph the loss
        loss_graph.append(main_loss.item())
        
        # View the loss within the epoch
        print(main_loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        main_loss.backward()
        optimizer.step()
        
    return main_loss

# %%
# You may switch the optimizer
def get_optimizer(net):
    optimizer = torch.optim.SGD(net.parameters(),
                                lr=0.1, # 0.001
                                weight_decay=1e-5,
                                momentum=0.5,
                                nesterov=False)
    return optimizer

# %%
# %%time
# %matplotlib inline

# Deep copy in order to train the network with the same initialized weights
trained_net = copy.deepcopy(untrained_net)
trained_net = trained_net.to(device)

# set loss function for the net
trained_net.criterion = nn.CrossEntropyLoss(ignore_index=-1)

# You can change the number of EPOCHS
EPOCH = 40

# switch to train mode (original untrained_net was set to eval mode)
trained_net.train()

optimizer = get_optimizer(trained_net)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    loss = train(train_loader, trained_net, optimizer, loss_graph, device)
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for trained net')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    print("Epoch: {} Loss: {}".format(e, loss))
# Out:
# Starting Training...
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 3.6773064136505127
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 3.0678491592407227
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.7154626846313477
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.5562291145324707
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.258295774459839
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.298304319381714
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.230147361755371
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.9911119937896729
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 2.090846300125122
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.9855148792266846
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.777268409729004
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.7459497451782227
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.831279993057251
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.576368808746338
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4563071727752686
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.6857420206069946
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4299319982528687
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.5940070152282715
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4517139196395874
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.5759506225585938
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.5572518110275269
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4025332927703857
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4575698375701904
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4073903560638428
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.4305647611618042
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3239493370056152
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.219037413597107
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3106480836868286
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3550945520401
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.504807949066162
# Epoch: 0 Loss: 1.504807949066162
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1895771026611328
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3353888988494873
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2448450326919556
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1942685842514038
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1310590505599976
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.087383508682251
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.5803561210632324
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0372329950332642
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1721121072769165
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.224548578262329
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1551134586334229
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2046149969100952
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2294610738754272
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1326937675476074
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.415921926498413
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2373480796813965
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0941238403320312
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1531156301498413
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3240097761154175
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1071429252624512
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.247727870941162
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.869926393032074
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1558917760849
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.227892518043518
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0383321046829224
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9426145553588867
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2096470594406128
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.336599349975586
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.276200294494629
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.9587385654449463
# Epoch: 1 Loss: 0.9587385654449463
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.065348744392395
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2938718795776367
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0675971508026123
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8619900941848755
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1301528215408325
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0827680826187134
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1608376502990723
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0832550525665283
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0456448793411255
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9260299205780029
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0211814641952515
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9032136797904968
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0498452186584473
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.902545154094696
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1588726043701172
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0472381114959717
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1448079347610474
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9890834093093872
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0663409233093262
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.105173945426941
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0547055006027222
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8990091681480408
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9062933921813965
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1675453186035156
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0479694604873657
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7737054824829102
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9856458306312561
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1776790618896484
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2677290439605713
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.9106237888336182
# Epoch: 2 Loss: 1.9106237888336182
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1149243116378784
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.006521224975586
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8550839424133301
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8749141097068787
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.002845287322998
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7715722918510437
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9915208220481873
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.3427354097366333
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8711761236190796
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.89225834608078
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0198651552200317
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.00050950050354
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9798657298088074
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9410717487335205
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8290888667106628
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8674106001853943
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9630621075630188
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0573245286941528
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9861302375793457
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1987091302871704
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8870295882225037
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.106173038482666
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9783575534820557
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9173577427864075
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9028677940368652
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8225870728492737
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7997884154319763
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0186342000961304
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0827163457870483
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.9382672905921936
# Epoch: 3 Loss: 0.9382672905921936
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7209838628768921
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7627590298652649
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0048140287399292
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7202075719833374
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7989322543144226
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.94442218542099
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9093267321586609
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9151120781898499
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9408162236213684
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8156835436820984
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8721593618392944
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9491952061653137
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8362491726875305
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9437128901481628
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1919645071029663
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9214348196983337
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0904009342193604
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9485415816307068
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8271508812904358
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9043505191802979
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8514077067375183
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9136887788772583
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.888786792755127
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.013593077659607
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8282705545425415
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8143388032913208
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0903936624526978
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9276376366615295
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6832886934280396
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.87828528881073
# Epoch: 4 Loss: 0.87828528881073
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0077265501022339
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8767493963241577
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6273517608642578
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7020348906517029
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9489086270332336
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9971040487289429
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6713407039642334
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9411897659301758
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.897071361541748
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9097698330879211
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8819843530654907
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.148762583732605
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.808570146560669
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7475935816764832
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8989244103431702
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7949883341789246
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9281005263328552
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8999848961830139
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8361103534698486
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7091931104660034
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.833828866481781
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8904508352279663
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8924278020858765
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8422392010688782
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6306453347206116
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8255138993263245
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8510112166404724
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.871824324131012
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0867093801498413
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.0847426652908325
# Epoch: 5 Loss: 1.0847426652908325
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.775232195854187
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9717298150062561
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8189636468887329
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9351525902748108
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7297385334968567
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8614148497581482
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7901322245597839
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.886087954044342
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7887200117111206
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.984221339225769
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7280964851379395
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0164159536361694
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9407059550285339
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9838790893554688
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0007387399673462
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8204021453857422
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8149581551551819
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9830553531646729
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1216115951538086
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1611979007720947
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.799577534198761
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8146508932113647
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7998253703117371
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0198756456375122
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7842965126037598
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.820895254611969
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6332974433898926
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8015115261077881
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7743704319000244
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.9688187837600708
# Epoch: 6 Loss: 0.9688187837600708
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0284253358840942
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0762107372283936
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8801102638244629
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9409391283988953
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8002556562423706
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8808121085166931
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7137517333030701
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7493024468421936
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9323936104774475
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8901953101158142
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8091928958892822
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8562490344047546
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9332106709480286
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9498835206031799
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7208605408668518
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7160802483558655
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7217365503311157
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6055970191955566
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7477911114692688
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8176707625389099
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9032871723175049
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.010891318321228
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6459080576896667
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8642956614494324
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8566939234733582
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7888684272766113
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6924068927764893
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8325443863868713
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.869907021522522
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.9044194221496582
# Epoch: 7 Loss: 0.9044194221496582
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8579956293106079
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8545615673065186
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8973417282104492
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.832711398601532
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7208750247955322
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7671132683753967
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8235853314399719
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8778449892997742
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0252702236175537
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8887296915054321
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.814294695854187
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0072814226150513
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7033898830413818
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8282303810119629
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7166431546211243
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7292276620864868
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7659615874290466
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8408340215682983
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9066393375396729
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8295758366584778
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8097643256187439
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9952321648597717
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7103577256202698
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7327848076820374
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8165677785873413
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7784333825111389
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.823346734046936
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7600634694099426
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.826177716255188
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.2516403198242188
# Epoch: 8 Loss: 1.2516403198242188
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6717901825904846
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6940834522247314
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.05685555934906
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9278247952461243
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7911711931228638
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8856785297393799
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7413495779037476
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8230568170547485
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6984918117523193
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7934560775756836
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9078464508056641
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7718521952629089
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7793777585029602
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6022506356239319
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6919639706611633
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7603544592857361
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6925992965698242
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8596410155296326
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8679785132408142
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.093741774559021
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.782137930393219
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6865658760070801
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6209341883659363
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6911112070083618
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6555389165878296
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7566030025482178
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9968934059143066
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0242853164672852
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6872662901878357
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.456221103668213
# Epoch: 9 Loss: 1.456221103668213
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5885488390922546
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.734347403049469
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.1456822156906128
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7974886894226074
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7929613590240479
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7490729093551636
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.775459885597229
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6081349849700928
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.872575581073761
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9504047632217407
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8817628026008606
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6893736124038696
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8709617257118225
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7211687564849854
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8032405376434326
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.690732479095459
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7284167408943176
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7261282801628113
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8152211308479309
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.013909935951233
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7658430337905884
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6867765188217163
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7180162072181702
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6788143515586853
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8296982049942017
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6989954113960266
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7520352005958557
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7402985692024231
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9101352095603943
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.6395648121833801
# Epoch: 10 Loss: 0.6395648121833801
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7955177426338196
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5953433513641357
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8212431073188782
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9145706295967102
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.843576192855835
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7443326711654663
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5827572345733643
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6660239100456238
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7178013324737549
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9577290415763855
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6700892448425293
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6407535076141357
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.599881649017334
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.679301917552948
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6845709681510925
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6155775785446167
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8608362078666687
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8566879630088806
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7891318202018738
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5737388730049133
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8128752112388611
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2104994058609009
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7541759014129639
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8942252993583679
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7493408918380737
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5664129853248596
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7570206522941589
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8318200707435608
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8898913860321045
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.7318515181541443
# Epoch: 11 Loss: 0.7318515181541443
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5809807777404785
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7431089282035828
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8529322147369385
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9365142583847046
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7541714906692505
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.869380533695221
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6558757424354553
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8185341954231262
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.565055787563324
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7024203538894653
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7388448715209961
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8145900964736938
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7484936118125916
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.0678439140319824
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7194494605064392
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6332207322120667
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7064658999443054
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7012866139411926
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7868118286132812
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8220997452735901
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8104575276374817
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8080403804779053
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6907258629798889
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7890557646751404
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7582423090934753
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7700414657592773
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8548410534858704
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6652894020080566
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8642963171005249
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.3618611097335815
# Epoch: 12 Loss: 1.3618611097335815
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6655003428459167
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7444301843643188
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 1.2271915674209595
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7761074304580688
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6821910738945007
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7725864052772522
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8613226413726807
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5521559715270996
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7248005867004395
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6744682192802429
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7957155108451843
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9595794677734375
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.768395185470581
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7267579436302185
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7790613174438477
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7395103573799133
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6484499573707581
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5957419872283936
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.795006513595581
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6849945187568665
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8969766497612
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7781276106834412
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8179596662521362
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5858171582221985
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8176628351211548
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6812660098075867
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8410398960113525
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6522339582443237
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8431586027145386
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.873112678527832
# Epoch: 13 Loss: 0.873112678527832
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.709244966506958
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6125470399856567
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8857085704803467
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6198373436927795
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5772169232368469
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8062977194786072
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6435695886611938
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9212173223495483
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7169802188873291
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6830174326896667
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5586161613464355
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9534125328063965
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7193909883499146
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6808497309684753
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.746712327003479
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5911208391189575
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6209354400634766
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5689572095870972
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9401723742485046
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.589899480342865
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7587594985961914
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6960015296936035
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6394733786582947
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8120701313018799
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7181961536407471
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6229326128959656
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8659731149673462
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5631771683692932
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7523084282875061
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.650348424911499
# Epoch: 14 Loss: 0.650348424911499
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.669411301612854
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.624639093875885
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6936492919921875
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6421551704406738
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6665638089179993
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6631445288658142
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8093529343605042
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7611663937568665
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6182450652122498
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9381650686264038
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7761431336402893
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7424207329750061
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7160583734512329
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7434312105178833
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6407665014266968
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5929571986198425
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7885899543762207
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8161429166793823
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7914559841156006
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7208330631256104
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5801091194152832
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5585088133811951
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7302650213241577
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.725633978843689
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6518450379371643
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8482919335365295
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.88088059425354
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7460806965827942
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5624871850013733
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.2895454168319702
# Epoch: 15 Loss: 1.2895454168319702
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7810871005058289
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.641128659248352
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6519182920455933
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6089413166046143
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.719240128993988
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8143672347068787
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6976161599159241
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.59952312707901
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9001976847648621
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# ...
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6548555493354797
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5833831429481506
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.593051016330719
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4470560848712921
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6362802982330322
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7060903906822205
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5450143218040466
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.533303439617157
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.48356062173843384
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7129221558570862
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5834569931030273
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.871525228023529
# Epoch: 34 Loss: 0.871525228023529
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6142348647117615
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6391909718513489
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7158793210983276
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6644405126571655
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7484418749809265
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5321184992790222
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5211293697357178
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6031697988510132
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9363076090812683
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5448870062828064
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6373822689056396
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7360549569129944
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6481728553771973
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6761927604675293
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5861903429031372
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5601491332054138
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6852476596832275
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5595371127128601
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.49787282943725586
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5047756433486938
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6875477433204651
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6862275004386902
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6543684005737305
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5836656093597412
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6174787282943726
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6852686405181885
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6286561489105225
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6456050872802734
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.603558361530304
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.7685827612876892
# Epoch: 35 Loss: 0.7685827612876892
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8339816331863403
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8204576373100281
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5255094170570374
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5626022219657898
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5871577858924866
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5067735314369202
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5815192461013794
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5702367424964905
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6814093589782715
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5705386400222778
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4419001638889313
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9109963178634644
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.60310298204422
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5723950266838074
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5775251388549805
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5049987435340881
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6203759908676147
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6258800625801086
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7109271883964539
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7079315185546875
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5210285186767578
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9485558271408081
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5109961628913879
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5034054517745972
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.569588840007782
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6894468665122986
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.688956081867218
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6072404980659485
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6148119568824768
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.5830545425415039
# Epoch: 36 Loss: 0.5830545425415039
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.43492305278778076
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6832614541053772
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5427529215812683
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5935013294219971
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6067982316017151
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7746732234954834
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4958440661430359
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5782633423805237
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.3897952139377594
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5086838006973267
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7010301351547241
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5268550515174866
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6710470914840698
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6388949751853943
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9318123459815979
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6094432473182678
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6291833519935608
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6867638826370239
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4993516206741333
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6647673845291138
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8101027011871338
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7318398952484131
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6479077935218811
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7575578093528748
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6526045203208923
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.48524731397628784
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7443333268165588
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5683639645576477
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6224861145019531
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.5022846460342407
# Epoch: 37 Loss: 0.5022846460342407
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6081013679504395
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.561762273311615
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5437458753585815
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7171432375907898
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5651019215583801
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8020008206367493
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.43966564536094666
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5235064625740051
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7488480806350708
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8348102569580078
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6548680663108826
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4408438801765442
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4795554578304291
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5218931436538696
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5836085677146912
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5970615744590759
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5734275579452515
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5902825593948364
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6634014248847961
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5767983198165894
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7085080146789551
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4885925352573395
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.80556720495224
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5165810585021973
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7279495596885681
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4773983657360077
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5795720219612122
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.62641441822052
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7233648300170898
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 0.7154276371002197
# Epoch: 38 Loss: 0.7154276371002197
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8694950342178345
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5860782861709595
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7576870322227478
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.39599284529685974
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5140799283981323
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6744027137756348
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.612691342830658
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6743987202644348
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6143149733543396
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.8120316863059998
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4780192971229553
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6726183891296387
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5085684061050415
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6629343628883362
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.615265965461731
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5207573175430298
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.6281343698501587
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5565474629402161
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5420128107070923
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4846462309360504
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.4999040365219116
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.7092239856719971
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.9263766407966614
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5059047341346741
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.41524162888526917
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5571591258049011
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5311402678489685
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5362923741340637
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# 0.5953673720359802
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# 1.101540446281433
# Epoch: 39 Loss: 1.101540446281433
# CPU times: user 1min 22s, sys: 32.9 s, total: 1min 55s
# Wall time: 8min 19s

# %%
def validate(val_loader, net):
    iou_arr = []
    val_loss = 0

    net.eval()

    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(val_loader):
            img, gt_seg_img = data.to(device), target.to(device)

            output = net(img)

            # Convert to numpy arrays
            if device != 'cpu':
                output = output.cpu()
                gt_seg_img = gt_seg_img.cpu()
            pred = torch.argmax(output, dim=1).numpy()[0]

            gt_np = gt_seg_img.numpy()[0]

            conf = eval_semantic_segmentation(pred[None], gt_np[None])

            iou_arr.append(conf['miou'])
    
    return val_loss, (sum(iou_arr) / len(iou_arr))

# %% [markdown]
# # Validation

# %%
# a validation loader is created with a transform that doesn't modify the data
voc_val_data = VOCSemanticSegmentationDataset(data_dir=DATASET_LOCATION + 'VOC2012', split='val')

def val_transform(in_data):
    img, seg_img = in_data

    img = np.rollaxis(img, 0, 3)
    img = transforms.ToPILImage()(np.uint8(img))
    img = transforms.ToTensor()(img)
    img = transforms.Normalize(mean=norm[0],std=norm[1])(img)

    return img, torch.from_numpy(seg_img).long()

voc_val_data_transformed = TransformDataset(voc_val_data, val_transform)

# epoch = one iteration over the entire dataset
# batch size = samples per batch within an epoch
# shuffle = Set to True if your data is ordered
# num_workers = number of subprocess to use when dataloading, set higher if you have many cpu cores
val_loader = DataLoader(voc_val_data_transformed, batch_size=1, shuffle=True, num_workers=10)

# %%
# %%time
print("mIoU over the training dataset:{}".format(validate(train_loader, trained_net)[1]))
# Out:
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([50, 21, 110, 110])
# output size is :  (110, 110)
# lfinal size is :  torch.Size([14, 21, 110, 110])
# mIoU over the training dataset:0.5225294358962788
# CPU times: user 9.93 s, sys: 900 ms, total: 10.8 s
# Wall time: 16 s

# %%
# %%time
print("mIoU over the validation dataset:{}".format(validate(val_loader, trained_net)[1]))
# Out:
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# output size is :  (500, 313)
# lfinal size is :  torch.Size([1, 21, 500, 313])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 331)
# lfinal size is :  torch.Size([1, 21, 500, 331])
# output size is :  (500, 334)
# lfinal size is :  torch.Size([1, 21, 500, 334])
# output size is :  (356, 500)
# lfinal size is :  torch.Size([1, 21, 356, 500])
# output size is :  (338, 500)
# lfinal size is :  torch.Size([1, 21, 338, 500])
# output size is :  (457, 500)
# lfinal size is :  torch.Size([1, 21, 457, 500])
# output size is :  (389, 500)
# lfinal size is :  torch.Size([1, 21, 389, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (273, 500)
# lfinal size is :  torch.Size([1, 21, 273, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (275, 500)
# lfinal size is :  torch.Size([1, 21, 275, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 366)
# lfinal size is :  torch.Size([1, 21, 500, 366])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 301)
# lfinal size is :  torch.Size([1, 21, 500, 301])
# output size is :  (318, 500)
# lfinal size is :  torch.Size([1, 21, 318, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (350, 500)
# lfinal size is :  torch.Size([1, 21, 350, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (338, 450)
# lfinal size is :  torch.Size([1, 21, 338, 450])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 374)
# lfinal size is :  torch.Size([1, 21, 500, 374])
# output size is :  (345, 500)
# lfinal size is :  torch.Size([1, 21, 345, 500])
# output size is :  (362, 500)
# lfinal size is :  torch.Size([1, 21, 362, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (476, 500)
# lfinal size is :  torch.Size([1, 21, 476, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (245, 300)
# lfinal size is :  torch.Size([1, 21, 245, 300])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (262, 350)
# lfinal size is :  torch.Size([1, 21, 262, 350])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 347)
# lfinal size is :  torch.Size([1, 21, 500, 347])
# output size is :  (344, 500)
# lfinal size is :  torch.Size([1, 21, 344, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (431, 500)
# lfinal size is :  torch.Size([1, 21, 431, 500])
# output size is :  (297, 500)
# lfinal size is :  torch.Size([1, 21, 297, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (281, 500)
# lfinal size is :  torch.Size([1, 21, 281, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (347, 500)
# lfinal size is :  torch.Size([1, 21, 347, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 357)
# lfinal size is :  torch.Size([1, 21, 500, 357])
# output size is :  (466, 500)
# lfinal size is :  torch.Size([1, 21, 466, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (349, 500)
# lfinal size is :  torch.Size([1, 21, 349, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 360)
# lfinal size is :  torch.Size([1, 21, 500, 360])
# output size is :  (500, 342)
# lfinal size is :  torch.Size([1, 21, 500, 342])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (396, 500)
# lfinal size is :  torch.Size([1, 21, 396, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (385, 500)
# lfinal size is :  torch.Size([1, 21, 385, 500])
# output size is :  (419, 343)
# lfinal size is :  torch.Size([1, 21, 419, 343])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (417, 500)
# lfinal size is :  torch.Size([1, 21, 417, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (151, 500)
# lfinal size is :  torch.Size([1, 21, 151, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 355)
# lfinal size is :  torch.Size([1, 21, 500, 355])
# output size is :  (323, 500)
# lfinal size is :  torch.Size([1, 21, 323, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (400, 500)
# lfinal size is :  torch.Size([1, 21, 400, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (400, 300)
# lfinal size is :  torch.Size([1, 21, 400, 300])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 400)
# lfinal size is :  torch.Size([1, 21, 500, 400])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (278, 500)
# lfinal size is :  torch.Size([1, 21, 278, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (293, 500)
# lfinal size is :  torch.Size([1, 21, 293, 500])
# output size is :  (429, 500)
# lfinal size is :  torch.Size([1, 21, 429, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (426, 320)
# lfinal size is :  torch.Size([1, 21, 426, 320])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (270, 360)
# lfinal size is :  torch.Size([1, 21, 270, 360])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (321, 500)
# lfinal size is :  torch.Size([1, 21, 321, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (500, 325)
# lfinal size is :  torch.Size([1, 21, 500, 325])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (344, 500)
# lfinal size is :  torch.Size([1, 21, 344, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (500, 500)
# lfinal size is :  torch.Size([1, 21, 500, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (400, 500)
# lfinal size is :  torch.Size([1, 21, 400, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (480, 360)
# lfinal size is :  torch.Size([1, 21, 480, 360])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 334)
# lfinal size is :  torch.Size([1, 21, 500, 334])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (429, 500)
# lfinal size is :  torch.Size([1, 21, 429, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (412, 500)
# lfinal size is :  torch.Size([1, 21, 412, 500])
# output size is :  (500, 350)
# lfinal size is :  torch.Size([1, 21, 500, 350])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (200, 300)
# lfinal size is :  torch.Size([1, 21, 200, 300])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 224)
# lfinal size is :  torch.Size([1, 21, 500, 224])
# output size is :  (476, 500)
# lfinal size is :  torch.Size([1, 21, 476, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (349, 500)
# lfinal size is :  torch.Size([1, 21, 349, 500])
# output size is :  (500, 350)
# lfinal size is :  torch.Size([1, 21, 500, 350])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 500)
# lfinal size is :  torch.Size([1, 21, 500, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (243, 500)
# lfinal size is :  torch.Size([1, 21, 243, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (377, 500)
# lfinal size is :  torch.Size([1, 21, 377, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (476, 500)
# lfinal size is :  torch.Size([1, 21, 476, 500])
# output size is :  (400, 500)
# lfinal size is :  torch.Size([1, 21, 400, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (361, 500)
# lfinal size is :  torch.Size([1, 21, 361, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (418, 500)
# lfinal size is :  torch.Size([1, 21, 418, 500])
# output size is :  (370, 500)
# lfinal size is :  torch.Size([1, 21, 370, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (281, 500)
# lfinal size is :  torch.Size([1, 21, 281, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (327, 500)
# lfinal size is :  torch.Size([1, 21, 327, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (363, 500)
# lfinal size is :  torch.Size([1, 21, 363, 500])
# output size is :  (342, 500)
# lfinal size is :  torch.Size([1, 21, 342, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (196, 500)
# lfinal size is :  torch.Size([1, 21, 196, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (500, 361)
# lfinal size is :  torch.Size([1, 21, 500, 361])
# output size is :  (500, 335)
# lfinal size is :  torch.Size([1, 21, 500, 335])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (295, 500)
# lfinal size is :  torch.Size([1, 21, 295, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (419, 500)
# lfinal size is :  torch.Size([1, 21, 419, 500])
# output size is :  (366, 500)
# lfinal size is :  torch.Size([1, 21, 366, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (369, 500)
# lfinal size is :  torch.Size([1, 21, 369, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (321, 500)
# lfinal size is :  torch.Size([1, 21, 321, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (339, 500)
# lfinal size is :  torch.Size([1, 21, 339, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 414)
# lfinal size is :  torch.Size([1, 21, 500, 414])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 273)
# lfinal size is :  torch.Size([1, 21, 500, 273])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 377)
# lfinal size is :  torch.Size([1, 21, 500, 377])
# output size is :  (500, 490)
# lfinal size is :  torch.Size([1, 21, 500, 490])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (359, 500)
# lfinal size is :  torch.Size([1, 21, 359, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (322, 400)
# lfinal size is :  torch.Size([1, 21, 322, 400])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (356, 500)
# lfinal size is :  torch.Size([1, 21, 356, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (411, 500)
# lfinal size is :  torch.Size([1, 21, 411, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (316, 500)
# lfinal size is :  torch.Size([1, 21, 316, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 409)
# lfinal size is :  torch.Size([1, 21, 500, 409])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (377, 500)
# lfinal size is :  torch.Size([1, 21, 377, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 380)
# lfinal size is :  torch.Size([1, 21, 500, 380])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (360, 270)
# lfinal size is :  torch.Size([1, 21, 360, 270])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (336, 448)
# lfinal size is :  torch.Size([1, 21, 336, 448])
# output size is :  (377, 500)
# lfinal size is :  torch.Size([1, 21, 377, 500])
# output size is :  (500, 424)
# lfinal size is :  torch.Size([1, 21, 500, 424])
# output size is :  (322, 500)
# lfinal size is :  torch.Size([1, 21, 322, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (389, 500)
# lfinal size is :  torch.Size([1, 21, 389, 500])
# output size is :  (319, 480)
# lfinal size is :  torch.Size([1, 21, 319, 480])
# output size is :  (363, 500)
# lfinal size is :  torch.Size([1, 21, 363, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (176, 500)
# lfinal size is :  torch.Size([1, 21, 176, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (404, 500)
# lfinal size is :  torch.Size([1, 21, 404, 500])
# output size is :  (500, 376)
# lfinal size is :  torch.Size([1, 21, 500, 376])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (397, 500)
# lfinal size is :  torch.Size([1, 21, 397, 500])
# output size is :  (392, 480)
# lfinal size is :  torch.Size([1, 21, 392, 480])
# output size is :  (269, 500)
# lfinal size is :  torch.Size([1, 21, 269, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (384, 500)
# lfinal size is :  torch.Size([1, 21, 384, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (342, 500)
# lfinal size is :  torch.Size([1, 21, 342, 500])
# output size is :  (329, 500)
# lfinal size is :  torch.Size([1, 21, 329, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (399, 500)
# lfinal size is :  torch.Size([1, 21, 399, 500])
# output size is :  (500, 500)
# lfinal size is :  torch.Size([1, 21, 500, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (433, 500)
# lfinal size is :  torch.Size([1, 21, 433, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (500, 492)
# lfinal size is :  torch.Size([1, 21, 500, 492])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (343, 500)
# lfinal size is :  torch.Size([1, 21, 343, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (326, 500)
# lfinal size is :  torch.Size([1, 21, 326, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (437, 480)
# lfinal size is :  torch.Size([1, 21, 437, 480])
# output size is :  (500, 391)
# lfinal size is :  torch.Size([1, 21, 500, 391])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 431)
# lfinal size is :  torch.Size([1, 21, 500, 431])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (357, 500)
# lfinal size is :  torch.Size([1, 21, 357, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (500, 400)
# lfinal size is :  torch.Size([1, 21, 500, 400])
# output size is :  (443, 500)
# lfinal size is :  torch.Size([1, 21, 443, 500])
# output size is :  (300, 400)
# lfinal size is :  torch.Size([1, 21, 300, 400])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 425)
# lfinal size is :  torch.Size([1, 21, 500, 425])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (322, 500)
# lfinal size is :  torch.Size([1, 21, 322, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (324, 500)
# lfinal size is :  torch.Size([1, 21, 324, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (307, 461)
# lfinal size is :  torch.Size([1, 21, 307, 461])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (413, 500)
# lfinal size is :  torch.Size([1, 21, 413, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 429)
# lfinal size is :  torch.Size([1, 21, 500, 429])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (367, 500)
# lfinal size is :  torch.Size([1, 21, 367, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (427, 500)
# lfinal size is :  torch.Size([1, 21, 427, 500])
# output size is :  (336, 500)
# lfinal size is :  torch.Size([1, 21, 336, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 343)
# lfinal size is :  torch.Size([1, 21, 500, 343])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (404, 500)
# lfinal size is :  torch.Size([1, 21, 404, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (500, 367)
# lfinal size is :  torch.Size([1, 21, 500, 367])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (357, 500)
# lfinal size is :  torch.Size([1, 21, 357, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (376, 500)
# lfinal size is :  torch.Size([1, 21, 376, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (369, 500)
# lfinal size is :  torch.Size([1, 21, 369, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 374)
# lfinal size is :  torch.Size([1, 21, 500, 374])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 417)
# lfinal size is :  torch.Size([1, 21, 500, 417])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (414, 500)
# lfinal size is :  torch.Size([1, 21, 414, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (353, 500)
# lfinal size is :  torch.Size([1, 21, 353, 500])
# output size is :  (230, 500)
# lfinal size is :  torch.Size([1, 21, 230, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (338, 500)
# lfinal size is :  torch.Size([1, 21, 338, 500])
# output size is :  (344, 500)
# lfinal size is :  torch.Size([1, 21, 344, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (288, 432)
# lfinal size is :  torch.Size([1, 21, 288, 432])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 400)
# lfinal size is :  torch.Size([1, 21, 500, 400])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (240, 320)
# lfinal size is :  torch.Size([1, 21, 240, 320])
# output size is :  (347, 500)
# lfinal size is :  torch.Size([1, 21, 347, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 347)
# lfinal size is :  torch.Size([1, 21, 500, 347])
# output size is :  (300, 500)
# lfinal size is :  torch.Size([1, 21, 300, 500])
# output size is :  (306, 500)
# lfinal size is :  torch.Size([1, 21, 306, 500])
# output size is :  (434, 500)
# lfinal size is :  torch.Size([1, 21, 434, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (344, 478)
# lfinal size is :  torch.Size([1, 21, 344, 478])
# output size is :  (500, 372)
# lfinal size is :  torch.Size([1, 21, 500, 372])
# output size is :  (500, 281)
# lfinal size is :  torch.Size([1, 21, 500, 281])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (331, 500)
# lfinal size is :  torch.Size([1, 21, 331, 500])
# output size is :  (336, 500)
# lfinal size is :  torch.Size([1, 21, 336, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (338, 450)
# lfinal size is :  torch.Size([1, 21, 338, 450])
# output size is :  (423, 480)
# lfinal size is :  torch.Size([1, 21, 423, 480])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (489, 500)
# lfinal size is :  torch.Size([1, 21, 489, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (332, 500)
# ...
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (400, 266)
# lfinal size is :  torch.Size([1, 21, 400, 266])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (315, 500)
# lfinal size is :  torch.Size([1, 21, 315, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 299)
# lfinal size is :  torch.Size([1, 21, 500, 299])
# output size is :  (316, 500)
# lfinal size is :  torch.Size([1, 21, 316, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (357, 500)
# lfinal size is :  torch.Size([1, 21, 357, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 500)
# lfinal size is :  torch.Size([1, 21, 500, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (406, 500)
# lfinal size is :  torch.Size([1, 21, 406, 500])
# output size is :  (330, 500)
# lfinal size is :  torch.Size([1, 21, 330, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (291, 412)
# lfinal size is :  torch.Size([1, 21, 291, 412])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (441, 500)
# lfinal size is :  torch.Size([1, 21, 441, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (212, 320)
# lfinal size is :  torch.Size([1, 21, 212, 320])
# output size is :  (391, 500)
# lfinal size is :  torch.Size([1, 21, 391, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (215, 288)
# lfinal size is :  torch.Size([1, 21, 215, 288])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (376, 500)
# lfinal size is :  torch.Size([1, 21, 376, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (351, 500)
# lfinal size is :  torch.Size([1, 21, 351, 500])
# output size is :  (326, 500)
# lfinal size is :  torch.Size([1, 21, 326, 500])
# output size is :  (402, 500)
# lfinal size is :  torch.Size([1, 21, 402, 500])
# output size is :  (500, 334)
# lfinal size is :  torch.Size([1, 21, 500, 334])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (364, 500)
# lfinal size is :  torch.Size([1, 21, 364, 500])
# output size is :  (327, 500)
# lfinal size is :  torch.Size([1, 21, 327, 500])
# output size is :  (349, 500)
# lfinal size is :  torch.Size([1, 21, 349, 500])
# output size is :  (338, 500)
# lfinal size is :  torch.Size([1, 21, 338, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (500, 373)
# lfinal size is :  torch.Size([1, 21, 500, 373])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (415, 500)
# lfinal size is :  torch.Size([1, 21, 415, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 473)
# lfinal size is :  torch.Size([1, 21, 500, 473])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (381, 500)
# lfinal size is :  torch.Size([1, 21, 381, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (480, 318)
# lfinal size is :  torch.Size([1, 21, 480, 318])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (332, 500)
# lfinal size is :  torch.Size([1, 21, 332, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (480, 356)
# lfinal size is :  torch.Size([1, 21, 480, 356])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (271, 500)
# lfinal size is :  torch.Size([1, 21, 271, 500])
# output size is :  (500, 338)
# lfinal size is :  torch.Size([1, 21, 500, 338])
# output size is :  (319, 500)
# lfinal size is :  torch.Size([1, 21, 319, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 341)
# lfinal size is :  torch.Size([1, 21, 500, 341])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (336, 448)
# lfinal size is :  torch.Size([1, 21, 336, 448])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (374, 500)
# lfinal size is :  torch.Size([1, 21, 374, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (400, 500)
# lfinal size is :  torch.Size([1, 21, 400, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (225, 400)
# lfinal size is :  torch.Size([1, 21, 225, 400])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (357, 500)
# lfinal size is :  torch.Size([1, 21, 357, 500])
# output size is :  (358, 500)
# lfinal size is :  torch.Size([1, 21, 358, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (327, 500)
# lfinal size is :  torch.Size([1, 21, 327, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (500, 255)
# lfinal size is :  torch.Size([1, 21, 500, 255])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (335, 500)
# lfinal size is :  torch.Size([1, 21, 335, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 353)
# lfinal size is :  torch.Size([1, 21, 500, 353])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (400, 500)
# lfinal size is :  torch.Size([1, 21, 400, 500])
# output size is :  (352, 500)
# lfinal size is :  torch.Size([1, 21, 352, 500])
# output size is :  (377, 500)
# lfinal size is :  torch.Size([1, 21, 377, 500])
# output size is :  (458, 342)
# lfinal size is :  torch.Size([1, 21, 458, 342])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 354)
# lfinal size is :  torch.Size([1, 21, 500, 354])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 355)
# lfinal size is :  torch.Size([1, 21, 500, 355])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (318, 500)
# lfinal size is :  torch.Size([1, 21, 318, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (334, 499)
# lfinal size is :  torch.Size([1, 21, 334, 499])
# output size is :  (500, 369)
# lfinal size is :  torch.Size([1, 21, 500, 369])
# output size is :  (500, 396)
# lfinal size is :  torch.Size([1, 21, 500, 396])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (318, 500)
# lfinal size is :  torch.Size([1, 21, 318, 500])
# output size is :  (500, 324)
# lfinal size is :  torch.Size([1, 21, 500, 324])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 353)
# lfinal size is :  torch.Size([1, 21, 500, 353])
# output size is :  (357, 500)
# lfinal size is :  torch.Size([1, 21, 357, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (281, 500)
# lfinal size is :  torch.Size([1, 21, 281, 500])
# output size is :  (361, 500)
# lfinal size is :  torch.Size([1, 21, 361, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (366, 500)
# lfinal size is :  torch.Size([1, 21, 366, 500])
# output size is :  (500, 380)
# lfinal size is :  torch.Size([1, 21, 500, 380])
# output size is :  (264, 352)
# lfinal size is :  torch.Size([1, 21, 264, 352])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (347, 500)
# lfinal size is :  torch.Size([1, 21, 347, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 174)
# lfinal size is :  torch.Size([1, 21, 500, 174])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (334, 500)
# lfinal size is :  torch.Size([1, 21, 334, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (337, 500)
# lfinal size is :  torch.Size([1, 21, 337, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (219, 300)
# lfinal size is :  torch.Size([1, 21, 219, 300])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (500, 375)
# lfinal size is :  torch.Size([1, 21, 500, 375])
# output size is :  (405, 500)
# lfinal size is :  torch.Size([1, 21, 405, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# output size is :  (500, 333)
# lfinal size is :  torch.Size([1, 21, 500, 333])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (383, 500)
# lfinal size is :  torch.Size([1, 21, 383, 500])
# output size is :  (363, 500)
# lfinal size is :  torch.Size([1, 21, 363, 500])
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# output size is :  (316, 500)
# lfinal size is :  torch.Size([1, 21, 316, 500])
# mIoU over the validation dataset:0.4193711452767525
# CPU times: user 1min 50s, sys: 15.5 s, total: 2min 6s
# Wall time: 2min 17s

# %%
# switch back to evaluation mode
trained_net.eval()

def add_img_txt_plot(fig, index, img, title, sub_plot_id, txt):
    ax = fig.add_subplot(sub_plot_id[0],sub_plot_id[1],sub_plot_id[2])
    plt.title(title + str(index))
    ax.text(10, 25, 'mIoU = {:_>8.6f}'.format(txt), fontsize=20, color='white')
    ax.imshow(img)

def get_nn_seg_img(net, data):
    img, gt_seg_img = data

    nn_seg_output = net.forward(img[None].cuda())

    # computing mIOU (quantitative measure of accuracy for network predictions)
    if device != 'cpu':
        nn_seg_img = torch.argmax(nn_seg_output, dim=1).cpu().numpy()[0]
    else:
        nn_seg_img = torch.argmax(nn_seg_output, dim=1).numpy()[0]

    gts = gt_seg_img.cpu().numpy()

    conf = eval_semantic_segmentation(nn_seg_img[None], gts[None])

    print("View count of pixels within each label category:")
    print(np.unique(gt_seg_img, return_counts=True))
    print(np.unique(nn_seg_img, return_counts=True))

    return nn_seg_img, conf['miou']

# Some relevant image indexes for a self-driving car
# Car = 119, 273, Bicycle = 225
img_119, seg_img_119 = voc_train_data[119]
img_273, seg_img_273 = voc_train_data[273]
img_225, seg_img_225 = voc_train_data[225]

# Get NN Output
nn_seg_img_119, miou_119 = get_nn_seg_img(trained_net, val_transform(voc_train_data[119]))
nn_seg_img_273, miou_273 = get_nn_seg_img(trained_net, val_transform(voc_train_data[273]))
nn_seg_img_225, miou_225 = get_nn_seg_img(trained_net, val_transform(voc_train_data[225]))

# Create the figure size
fig = plt.figure(figsize=(20,15))
# Car image 119
add_img_plot(fig, 119, np.rollaxis(img_119.astype(int), 0, 3), 'Image ', [3,3,1])
add_img_plot(fig, 119, colorize_mask(seg_img_119), 'GT Segmented Image ', [3,3,2])
add_img_txt_plot(fig, 119, colorize_mask(nn_seg_img_119), 'NN Segmented Image ', [3,3,3], miou_119)
# Car image 273
add_img_plot(fig, 273, np.rollaxis(img_273.astype(int), 0, 3), 'Image ', [3,3,4])
add_img_plot(fig, 273, colorize_mask(seg_img_273), 'Segmented Image ', [3,3,5])
add_img_txt_plot(fig, 273, colorize_mask(nn_seg_img_273), 'NN Segmented Image ', [3,3,6], miou_273)
# Bicycle image 225
add_img_plot(fig, 225, np.rollaxis(img_225.astype(int), 0, 3), 'Image ', [3,3,7])
add_img_plot(fig, 225, colorize_mask(seg_img_225), 'Segmented Image ', [3,3,8])
add_img_txt_plot(fig, 225, colorize_mask(nn_seg_img_225), 'NN Segmented Image ', [3,3,9], miou_225)
# Out:
# output size is :  (333, 500)
# lfinal size is :  torch.Size([1, 21, 333, 500])
# View count of pixels within each label category:
# (array([-1,  0,  7, 15]), array([  4943, 142234,  15733,   3590]))
# (array([ 0,  7,  8, 12]), array([141950,  20090,   4252,    208]))
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# View count of pixels within each label category:
# (array([-1,  0,  7, 15]), array([  3684, 150374,  32709,    733]))
# (array([0, 7]), array([153346,  34154]))
# output size is :  (375, 500)
# lfinal size is :  torch.Size([1, 21, 375, 500])
# View count of pixels within each label category:
# (array([-1,  0,  2,  7, 15]), array([ 12802, 164053,   4518,    673,   5454]))
# (array([ 0, 15]), array([184026,   3474]))
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
